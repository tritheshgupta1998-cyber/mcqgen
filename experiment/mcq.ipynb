# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain_openai import ChatOpenAI

# %%
from dotenv import load_dotenv

load_dotenv()  # take environment variable from .env.
# Out:
# True

# %%
KEY=os.getenv("OPENAI_API_KEY")

# %%
print(KEY)
# Out:
# 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

# %%
llm=ChatOpenAI(openai_api_key=KEY,model_name="gpt-3.5-turbo", temperature=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 llm=ChatOpenAI(openai_api_key=KEY,model_name="gpt-3.5-turbo", temperature=0.3)
#
# NameError: name 'KEY' is not defined
